# %%
import sys

from dataset_curation.wikipedia.preprocess_wikipedia import preprocess_wikipedia

print("Imports OK:", "preprocess_wikipedia" in dir())

# Quick smoke test with a tiny limit
stats = preprocess_wikipedia(
    dataset_name="wikimedia/wikipedia",
    dataset_config="20231101.en",
    output_path="data/wikipedia.jsonl",
    max_records=500000,
)
# Out:
# Imports OK: True
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# Preprocessing Wikipedia: 0it [00:00, ?it/s]

# %%
# OpenWebText smoke test
from dataset_curation.openwebtext.preprocess_openwebtext import preprocess_openwebtext

print("OpenWebText import OK:", "preprocess_openwebtext" in dir())

# Quick smoke test with a tiny limit
stats_owt = preprocess_openwebtext(
    dataset_name="openwebtext",
    output_path="data/openwebtext.jsonl",
    max_records=500000,
)
print("OpenWebText smoke stats:", stats_owt)
# Out:
# OpenWebText import OK: True
# ...
# Resolving data files:   0%|          | 0/80 [00:00<?, ?it/s]
# Preprocessing OpenWebText: 0it [00:00, ?it/s]
# OpenWebText smoke stats: {'total': 500000, 'kept': 499874, 'filtered_short': 4, 'filtered_lang': 122, 'filtered_dupe': 0, 'filtered_missing': 0, 'output_path': 'data/openwebtext.jsonl'}

# %%
# !PYTHONPATH=. python tokenizer/train_tokenizer.py
# Out:
# [00:01:13] Pre-processing sequences       ██████████████████ 1295432  /        0

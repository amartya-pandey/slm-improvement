# %%
import sys

from dataset_curation.wikipedia.preprocess_wikipedia import preprocess_wikipedia

print("Imports OK:", "preprocess_wikipedia" in dir())

# Quick smoke test with a tiny limit
stats = preprocess_wikipedia(
    dataset_name="wikimedia/wikipedia",
    dataset_config="20231101.en",
    output_path="data/wikipedia_smoke.jsonl",
    max_records=5,
)
print(stats)
# Out:
# Imports OK: True
# Preprocessing Wikipedia: 4it [00:03,  1.15it/s]
# {'total': 5, 'kept': 5, 'filtered_short': 0, 'filtered_lang': 0, 'filtered_dupe': 0, 'output_path': 'data/wikipedia_smoke.jsonl'}
